# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
basepath = 'A:/Test/TrackMatch/trackmatching4aff-m222-pl001/TrackMatching4Aff/00_00'
csv_all = os.path.join(basepath, 'aff_all.csv')
csv_5 = os.path.join(basepath, 'aff_1-5.csv')
csv_6 = os.path.join(basepath, 'aff_6-.csv')

# %%
df_all = pd.read_csv(csv_all)
df_5 = pd.read_csv(csv_5)
df_6 = pd.read_csv(csv_6)
print(df_all)
# Out:
#           a             b         c         d         p         q  \
# 0 -0.000631  4.816986e-07  0.000001 -0.000631  0.000272 -0.000768
#
#           a_err         b_err         c_err         d_err  p_err  q_err
# 0  5.821341e-09  1.033518e-08  5.412622e-09  9.609546e-09    0.0    0.0

# %%
x = [0]
print(x)
# Out:
# [0]

# %%
plt.plot(0.00394135987300500945808499919202, 'x', label='currend data')
plt.plot(df_all['b'] / df_all['a'][0], 'x', label='all data')
plt.plot(df_5['b'] / df_5['a'][0], 'x', label='vy < 6')
plt.plot(df_6['b'] / df_6['a'][0], 'x', label='vy > 6')
plt.ylabel(r'b / a $\simeq$[rad]')
plt.legend()
plt.savefig('A:/Test/TrackMatch/trackmatching4aff-m222-pl001/TrackMatching4Aff/00_00/comp_ba.png', dpi=300)
plt.show()
